# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#1: create any list from you 2D List-to-Dataframe Conversion Given a 2D List, convert it into corresponding dataframe and display it.
x=[10,20,30,40,50]
y=[100,200,300,400,500]
df=pd.DataFrame((x,y))
df
# Out:
#      0    1    2    3    4
# 0   10   20   30   40   50
# 1  100  200  300  400  500

# %%
df.plot()
plt.show()

# %%
#2: create any dic from you then Dictionary-to-Dataframe ConversionGiven a dictionary, convert it into corresponding dataframe and display it
area={"Rectangle" : 6 , 
      "Square" : 16,
      " Circle" : 28.27}
perimeter = {"Rectangle" : 10 , 
      "Square" : 16,
      " Circle" : 18.84}
data=pd.DataFrame({"Areas": area , "Perimeters":perimeter})
data
# Out:
#            Areas  Perimeters
# Rectangle   6.00       10.00
# Square     16.00       16.00
#  Circle    28.27       18.84

# %%
data.plot()
plt.show()

# %%
#3:Selecting all the rows from the given dataframe in which ‘Percentage’ is greater than 80 using basic method.

record = {  
 'Name': ['Ankit', 'Amit', 'Aishwarya', 'Priyanka', 'Priya', 'Shaurya' ],
 'Age': [21, 19, 20, 18, 17, 21],
 'Stream': ['Math', 'Commerce', 'Science', 'Math', 'Math', 'Science'],
 'Percentage': [88, 92, 95, 70, 65, 78] }

columns = ['Name', 'Age', 'Stream', 'Percentage']

df=pd.DataFrame(record)

df_bigger_than_80=df[df['Percentage'] > 80]
df_bigger_than_80
# Out:
#         Name  Age    Stream  Percentage
# 0      Ankit   21      Math          88
# 1       Amit   19  Commerce          92
# 2  Aishwarya   20   Science          95

# %%
df_bigger_than_80.plot()
plt.show()
